# %% [markdown]
# <a href="https://colab.research.google.com/github/hydrationn/Machine-DeepLearning/blob/main/DeepLearning/assignment/%EA%B3%BC%EC%A0%9C5_2_Sequence_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Model 2: LSTM

# %%
# Import package

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.utils.data as data_utils
import torchvision
import torchvision.transforms as transforms

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
# GPU/CPU setting

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

random.seed(777)
torch.manual_seed(777)
if device == 'cuda':
  torch.cuda.manual_seed_all(777)
# Out:
# cuda

# %%
# import dataset

import yfinance as yf

aapl = yf.download('AAPL', start='2019-01-01', end='2023-12-31')
googl = yf.download('GOOGL', start='2019-01-01', end='2023-12-31')
aapl
googl
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-02   51.360001   53.039501   51.264000   52.734001   52.734001
# 2019-01-03   52.533501   53.313000   51.118500   51.273499   51.273499
# 2019-01-04   52.127998   54.000000   51.842999   53.903500   53.903500
# 2019-01-07   54.048500   54.134998   53.132000   53.796001   53.796001
# 2019-01-08   54.299999   54.667500   53.417500   54.268501   54.268501
# ...                ...         ...         ...         ...         ...
# 2023-12-22  140.770004  141.990005  140.710007  141.490005  141.490005
# 2023-12-26  141.589996  142.679993  141.190002  141.520004  141.520004
# 2023-12-27  141.589996  142.080002  139.889999  140.369995  140.369995
# 2023-12-28  140.779999  141.139999  139.750000  140.229996  140.229996
# 2023-12-29  139.630005  140.360001  138.779999  139.690002  139.690002
#
#               Volume
# Date
# 2019-01-02  31868000
# 2019-01-03  41960000
# 2019-01-04  46022000
# 2019-01-07  47446000
# 2019-01-08  35414000
# ...              ...
# 2023-12-22  26514600
# 2023-12-26  16780300
# 2023-12-27  19628600
# 2023-12-28  16045700
# 2023-12-29  18727200
#
# [1258 rows x 6 columns]

# %%
# Data preprocessing

from sklearn.preprocessing import MinMaxScaler

def preprocess_data(data):
    df = pd.DataFrame(data['Close'])
    data_values = df.values.astype(float)
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data_values)
    return scaled_data, scaler

data_aapl, scaler_aapl = preprocess_data(aapl)
data_googl, scaler_googl = preprocess_data(googl)

train_ratio = 0.8
split_aapl = int(train_ratio * len(data_aapl))
split_googl = int(train_ratio * len(data_googl))

aapl_train = data_aapl[:split_aapl, :]
aapl_test = data_aapl[split_aapl:, :]
googl_train = data_googl[:split_googl, :]
googl_test = data_googl[split_googl:, :]

# %%
# Create sequences

def create_sequences(data, seq_length):
    x, y = [], []
    for i in range(seq_length, len(data)):
        x.append(data[i-seq_length:i, 0])
        y.append(data[i, 0])
    x = np.array(x)
    y = np.array(y)
    return x, y

x_train_aapl, y_train_aapl = create_sequences(aapl_train, sequence_length)
x_test_aapl, y_test_aapl = create_sequences(aapl_test, sequence_length)
x_train_googl, y_train_googl = create_sequences(googl_train, sequence_length)
x_test_googl, y_test_googl = create_sequences(googl_test, sequence_length)

# %%
# Convert to PyTorch tensors

x_train_aapl, y_train_aapl = torch.tensor(x_train_aapl).float(), torch.tensor(y_train_aapl).float()
x_test_aapl, y_test_aapl = torch.tensor(x_test_aapl).float(), torch.tensor(y_test_aapl).float()
x_train_googl, y_train_googl = torch.tensor(x_train_googl).float(), torch.tensor(y_train_googl).float()
x_test_googl, y_test_googl = torch.tensor(x_test_googl).float(), torch.tensor(y_test_googl).float()

# %%
# Batch generation

batch_size = 20
train_loader_aapl = DataLoader(list(zip(x_train_aapl, y_train_aapl)), batch_size=batch_size, shuffle=True)
test_loader_aapl = DataLoader(list(zip(x_test_aapl, y_test_aapl)), batch_size=batch_size, shuffle=False)
train_loader_googl = DataLoader(list(zip(x_train_googl, y_train_googl)), batch_size=batch_size, shuffle=True)
test_loader_googl = DataLoader(list(zip(x_test_googl, y_test_googl)), batch_size=batch_size, shuffle=False)

# %%
# Model

class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, sequence_length, num_layers, device):
        super(LSTM, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.sequence_length = sequence_length
        self.num_layers = num_layers
        self.device = device
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size * sequence_length, 1)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(self.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(self.device)
        out, _ = self.lstm(x, (h0, c0))
        out = out.reshape(out.shape[0], -1)
        out = self.fc(out)
        return out

# %%
# Hyperparameters

input_size = 1
hidden_size = 64
num_layers = 2
learning_rate = 0.001
num_epochs = 100

model_lstm_googl = LSTM(input_size, hidden_size, sequence_length, num_layers, device).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model_lstm_googl.parameters(), lr=learning_rate)

# %%
# Train

losses_aapl = []
for epoch in range(num_epochs):
    model_lstm_googl.train()
    epoch_losses = []
    for inputs, targets in train_loader_aapl:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model_lstm_googl(inputs.unsqueeze(-1))
        loss = criterion(outputs.squeeze(-1), targets)
        loss.backward()
        optimizer.step()
        epoch_losses.append(loss.item())
    losses_aapl.append(np.mean(epoch_losses))
    print(f'Epoch {epoch+1}/{num_epochs}, AAPL Train Loss: {np.mean(epoch_losses):.6f}')
# Out:
# Epoch 1/100, AAPL Train Loss: 0.070783
# Epoch 2/100, AAPL Train Loss: 0.002760
# Epoch 3/100, AAPL Train Loss: 0.001318
# Epoch 4/100, AAPL Train Loss: 0.001212
# Epoch 5/100, AAPL Train Loss: 0.001184
# Epoch 6/100, AAPL Train Loss: 0.001202
# Epoch 7/100, AAPL Train Loss: 0.001192
# Epoch 8/100, AAPL Train Loss: 0.001164
# Epoch 9/100, AAPL Train Loss: 0.001125
# Epoch 10/100, AAPL Train Loss: 0.001128
# Epoch 11/100, AAPL Train Loss: 0.001188
# Epoch 12/100, AAPL Train Loss: 0.001115
# Epoch 13/100, AAPL Train Loss: 0.001078
# Epoch 14/100, AAPL Train Loss: 0.001046
# Epoch 15/100, AAPL Train Loss: 0.001085
# Epoch 16/100, AAPL Train Loss: 0.001050
# Epoch 17/100, AAPL Train Loss: 0.001010
# Epoch 18/100, AAPL Train Loss: 0.000972
# Epoch 19/100, AAPL Train Loss: 0.000942
# Epoch 20/100, AAPL Train Loss: 0.000901
# Epoch 21/100, AAPL Train Loss: 0.000982
# Epoch 22/100, AAPL Train Loss: 0.000891
# Epoch 23/100, AAPL Train Loss: 0.000884
# Epoch 24/100, AAPL Train Loss: 0.000810
# Epoch 25/100, AAPL Train Loss: 0.000798
# Epoch 26/100, AAPL Train Loss: 0.000743
# Epoch 27/100, AAPL Train Loss: 0.000698
# Epoch 28/100, AAPL Train Loss: 0.000729
# Epoch 29/100, AAPL Train Loss: 0.000664
# Epoch 30/100, AAPL Train Loss: 0.000705
# Epoch 31/100, AAPL Train Loss: 0.000649
# Epoch 32/100, AAPL Train Loss: 0.000786
# Epoch 33/100, AAPL Train Loss: 0.000712
# Epoch 34/100, AAPL Train Loss: 0.000708
# Epoch 35/100, AAPL Train Loss: 0.000765
# Epoch 36/100, AAPL Train Loss: 0.000597
# Epoch 37/100, AAPL Train Loss: 0.000529
# Epoch 38/100, AAPL Train Loss: 0.000582
# Epoch 39/100, AAPL Train Loss: 0.000555
# Epoch 40/100, AAPL Train Loss: 0.000537
# Epoch 41/100, AAPL Train Loss: 0.000581
# Epoch 42/100, AAPL Train Loss: 0.000538
# Epoch 43/100, AAPL Train Loss: 0.000562
# Epoch 44/100, AAPL Train Loss: 0.000568
# Epoch 45/100, AAPL Train Loss: 0.000617
# Epoch 46/100, AAPL Train Loss: 0.000488
# Epoch 47/100, AAPL Train Loss: 0.000514
# Epoch 48/100, AAPL Train Loss: 0.000474
# Epoch 49/100, AAPL Train Loss: 0.000438
# Epoch 50/100, AAPL Train Loss: 0.000470
# Epoch 51/100, AAPL Train Loss: 0.000501
# Epoch 52/100, AAPL Train Loss: 0.000463
# Epoch 53/100, AAPL Train Loss: 0.000438
# Epoch 54/100, AAPL Train Loss: 0.000431
# Epoch 55/100, AAPL Train Loss: 0.000533
# Epoch 56/100, AAPL Train Loss: 0.000386
# Epoch 57/100, AAPL Train Loss: 0.000428
# Epoch 58/100, AAPL Train Loss: 0.000385
# Epoch 59/100, AAPL Train Loss: 0.000472
# Epoch 60/100, AAPL Train Loss: 0.000417
# Epoch 61/100, AAPL Train Loss: 0.000366
# Epoch 62/100, AAPL Train Loss: 0.000388
# Epoch 63/100, AAPL Train Loss: 0.000454
# Epoch 64/100, AAPL Train Loss: 0.000386
# Epoch 65/100, AAPL Train Loss: 0.000404
# Epoch 66/100, AAPL Train Loss: 0.000364
# Epoch 67/100, AAPL Train Loss: 0.000384
# Epoch 68/100, AAPL Train Loss: 0.000401
# Epoch 69/100, AAPL Train Loss: 0.000301
# Epoch 70/100, AAPL Train Loss: 0.000319
# Epoch 71/100, AAPL Train Loss: 0.000430
# Epoch 72/100, AAPL Train Loss: 0.000356
# Epoch 73/100, AAPL Train Loss: 0.000325
# Epoch 74/100, AAPL Train Loss: 0.000362
# Epoch 75/100, AAPL Train Loss: 0.000295
# Epoch 76/100, AAPL Train Loss: 0.000294
# Epoch 77/100, AAPL Train Loss: 0.000380
# Epoch 78/100, AAPL Train Loss: 0.000303
# Epoch 79/100, AAPL Train Loss: 0.000309
# Epoch 80/100, AAPL Train Loss: 0.000427
# Epoch 81/100, AAPL Train Loss: 0.000288
# Epoch 82/100, AAPL Train Loss: 0.000276
# Epoch 83/100, AAPL Train Loss: 0.000272
# Epoch 84/100, AAPL Train Loss: 0.000295
# Epoch 85/100, AAPL Train Loss: 0.000296
# Epoch 86/100, AAPL Train Loss: 0.000344
# Epoch 87/100, AAPL Train Loss: 0.000258
# Epoch 88/100, AAPL Train Loss: 0.000287
# Epoch 89/100, AAPL Train Loss: 0.000265
# Epoch 90/100, AAPL Train Loss: 0.000278
# Epoch 91/100, AAPL Train Loss: 0.000275
# Epoch 92/100, AAPL Train Loss: 0.000253
# Epoch 93/100, AAPL Train Loss: 0.000324
# Epoch 94/100, AAPL Train Loss: 0.000324
# Epoch 95/100, AAPL Train Loss: 0.000284
# Epoch 96/100, AAPL Train Loss: 0.000461
# Epoch 97/100, AAPL Train Loss: 0.000334
# Epoch 98/100, AAPL Train Loss: 0.000278
# Epoch 99/100, AAPL Train Loss: 0.000267
# Epoch 100/100, AAPL Train Loss: 0.000274

# %%
# Validation

model_lstm_googl.eval()
train_pred = model_lstm_googl(x_train_aapl.unsqueeze(-1).to(device)).squeeze().detach().cpu().numpy()
test_pred = model_lstm_googl(x_test_aapl.unsqueeze(-1).to(device)).squeeze().detach().cpu().numpy()

val_losses_aapl = []
with torch.no_grad():
    for inputs, targets in test_loader_aapl:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model_lstm_googl(inputs.unsqueeze(-1))
        val_loss = criterion(outputs.squeeze(-1), targets)
        val_losses_aapl.append(val_loss.item())
print(f'AAPL Validation Loss: {np.mean(val_losses_aapl):.6f}')
# Out:
# AAPL Validation Loss: 0.000261

# %%
# Plot

total_pred = np.concatenate([train_pred, test_pred])

plt.figure(figsize=(10, 6))
plt.plot(np.ones(100) * len(train_pred), np.linspace(0, 1, 100), '--', linewidth=0.6)
plt.plot(data_aapl, '--')
plt.plot(total_pred, 'b--')
plt.legend(['Train Boundary', 'Actual', 'Prediction'])
plt.title('AAPL: Prediction vs Actual')
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.show()
